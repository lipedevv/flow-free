# %% [markdown]
# # FlowFree - Google Colab\nEdite `REPO_URL` para apontar para o seu repositorio no GitHub.

# %%
REPO_URL = "https://github.com/seu-usuario/FlowFree.git"  # <-- troque aqui\nBRANCH = "main"\nFOLDER_NAME = "FlowFree"\nLAUNCH_ARGS = "--share --always-high-vram"  # ex: --preset anime --share --always-high-vram\n\n!pip install -q pygit2==1.15.1\n%cd /content\n!rm -rf {FOLDER_NAME}\n!git clone -b $BRANCH $REPO_URL $FOLDER_NAME\n%cd /content/$FOLDER_NAME\n\n!python flowfree_entry.py $LAUNCH_ARGS\n
